# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Flujos de control

# %% [markdown]
# ## Ejercicio Extra
# Programa una calculadora que
#
# * Pregunte qué operación quieres realizar (multiplicación/división/suma/resta/potencia/salir)
# * Pida dos números
# * Realice la operación
# * Siga funcionando hasta que el usuario elija salir
#
# #### Bonus:
# * Que guarde todas las operaciones realizadas y las imprima por pantalla cuando el usuario elija esa opción
# * Que sea robusta frente a entradas erróneas del usuario o frente a operaciones como dividir por 0

# %%
import math
import pprint
import time

# %%
print("Hola, soy tu calculadora.")
num_1 = input("Dame un primer número:") # pido al usuario que meta un primer número
num_2 = input("Dame un segundo número:") # pido al usuario un segundo número
num_1 = num_1.replace(",",".") # por si el ususario mete mal un decimal, hago dos replace para cada número
num_2 = num_2.replace(",",".")
num_1 = float(num_1) # los transformo a float
num_2 = float(num_2)

operacion = input("¿Qué operación quieres realizar? multiplicación/división/suma/resta/potencia/salir").lower() # pregunto por la operación

historial = [] # creo una lista vacía para ir metiendo el historial de lo que ha introducido el usuario

while  # sé que hay que hacer un while, pero ya no sé seguir
    if operacion == "multiplicación":
        print(num_1 * num_2)
    elif operacion == "división":
        print(num_1 / num_2)
    elif operacion == "suma":
        print(num_1 + num_2)
    elif operacion == "resta":
        print(num_1 - num_2)
    elif operacion == "potencia":
        print(num_1 ** num_2)
    else:
        print("No entiendo qué quieres hacer.")
# Out:
# Hola, soy tu calculadora.
# 112

# %%
# corregido:


num1 = float(input("Dame un primer número:")) # pido al usuario que meta un primer número y lo transformo a float
num2 = float(input("Dame un segundo número:")) # pido al usuario
var = [num1, num2] 

operacion = input("¿Qué operación quieres realizar? 1(multiplicación)/2(división)/3(suma)/4(resta)/5(potencia)/6(salir)")

match operacion:
    case "1":
        print(num1 * num2)
    case "2":
        print(num1 / num2)
    case "3":
        print(num1 + num2)
    case "4":
        print(num1 - num2)
    case "5":
        print(num1 ** num2)
    case "6":
        task = "salir"
# Out:
# 0.0
