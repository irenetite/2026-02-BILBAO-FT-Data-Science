# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 0
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
print("¿Por qué esta magnífica tecnología científica, \
      \n\t que ahorra trabajo y nos hace la vida más fácil, \
      \n\t\t nos aporta tan poca felicidad? \
      \n\t\t\t La respuesta está, simplemente: porque aún no hemos aprendido a usarla con tino. \
      \n\"Albert Einstein\"")
# Out:
# ¿Por qué esta magnífica tecnología científica,
# 	 que ahorra trabajo y nos hace la vida más fácil,
# 		 nos aporta tan poca felicidad?
# 			 La respuesta está, simplemente: porque aún no hemos aprendido a usarla con tino.
# "Albert Einstein"

# %% [markdown]
# ## Ejercicio 1
# 1. Escribe el nombre de la calle de tu domicilio en una variable
# 2. Escribe el numero de la calle en otra
# 3. Ciudad en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Imprime las 4 variables concatenadas por pantalla
# 6. Crea una quinta variable que concatene todas ellas
# 7. Imprímela por pantalla

# %%
kalea = ("Uriortu")
num_kalea = ("2")
ciudad = ("Bilbao")
cod_postal = ("48007")
print(kalea, num_kalea, ciudad, cod_postal)
direcc = kalea + " " + num_kalea + " " + ciudad + " " +cod_postal
print(direcc)

kalea = ("Uriortu")
num_kalea = (2)
ciudad = ("Bilbao")
cod_postal = (48007)
print(kalea, num_kalea, ciudad, cod_postal)
direcc = kalea + " " + str(num_kalea) + " " + ciudad + " " +str(cod_postal)
print(direcc)
# Out:
# Uriortu 2 Bilbao 48007
# Uriortu 2 Bilbao 48007
# Uriortu 2 Bilbao 48007
# Uriortu 2 Bilbao 48007

# %% [markdown]
# ## Ejercicio 2
# Repite el ejercicio 1, pero pidiendo estos datos al usuario mediante un input(), imprimiendo a continuación la dirección completa

# %%
print("Buenas, ¿en qué calle vives?")
kalea = input("Buenas, ¿en qué calle vives?")
num_kalea = input("¿En qué número?")
ciudad = input("¿Y cuál es tu ciudad?")
cod_postal = int(input("¿Y su código postal?"))
print(f"Gracias. Hemos anotado que tu dirección es: {kalea}, {num_kalea}, {ciudad}, {cod_postal}. Muchas gracias")
# Out:
# Buenas, ¿en qué calle vives?
# Gracias. Hemos anotado que tu dirección es: Uriortu, 2, Bilbao, 48007. Muchas gracias

# %% [markdown]
# ## Ejercicio 3
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. import = 40
# 6. 81mi_variable = "Agua"
# 7. mi_variable10 = 6

# %%
# 1:
# Esta variable es correcta, no tiene ningún error
mi_variable = "Economía"

# %%
# 2:
# Está incorrecta. Si la variable es str tiene que abrirse con comillas, pero también cerrarse.
otra_var = "Ejercicio
# Out:
#   Cell In[63], line 3
#     otra_var = "Ejercicio
#                ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
# 3:
# True se trata de una palabra reservada, no se puede utilizar para nombrar una variable.
True = "Ejercicio"
# Out:
#   Cell In[31], line 3
#     True = "Ejercicio"
#     ^
# SyntaxError: cannot assign to True

# %%
# 4:
# Mal. Una variable no puede tener espacios. Todos los caracteres deben ser letras o números
mi variab1e = "Alpha"
# Out:
#   Cell In[32], line 3
#     mi variab1e = "Alpha"
#        ^
# SyntaxError: invalid syntax

# %%
# 5:
# Import se trata de una palabra reservada, así que no se puede utilizar.
import = 40
# Out:
#   Cell In[33], line 3
#     import = 40
#            ^
# SyntaxError: invalid syntax

# %%
# 6:
# El nombre de las variables no puede comenzar con números.
81mi_variable = "Agua"
# Out:
#   Cell In[34], line 3
#     81mi_variable = "Agua"
#      ^
# SyntaxError: invalid decimal literal

# %%
# 7:
# Esta está bien, no hay nada que pueda dar error.
mi_variable10 = 6

# %% [markdown]
# ## Ejercicio 4
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = C × (9 / 5) + 32

# %%
celsius = float(input("Inserta los grados Celsius:"))
fahrenheit = celsius * (9 / 5) + 32
conversión = print(f"La equivalencia en grados Fahrenheit es {fahrenheit}")
# Out:
# La equivalencia en grados Fahrenheit es 77.0

# %% [markdown]
# ## Ejercicio 5
# Comenta  el Ejercicio 4. Pon un comentario multilinea y haz comentarios de cada linea de código

# %%
'''
Voy a realizar un input que devuelva un output con la conversión de grados Celsius a Fahrenheit.
Como cada grado Celsius equivale a 33,8 grados Fahreneit, usaremos la siguiente fórmula:
F = C x (9 / 5) + 32
'''

celsius = float(input("Inserta los grados Celsius:")) # Aquí solicito los grados Celsius que queremos convertir. Lo he puesto como float porque los grados rara vez son números enteros
fahrenheit = celsius * (9 / 5) + 32 # Aplico la fórmula para obtener los grados Fahrenheit
conversión = print(f"La equivalencia en grados Fahrenheit es {fahrenheit}") # Imprimo el resultado obtenido por el conversor
# Out:
# La equivalencia en grados Fahrenheit es 75.2
