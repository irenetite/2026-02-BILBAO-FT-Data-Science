# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# ¿Dónde viven las mujeres más seguras? Un análisis global de seguridad femenina

# %% [markdown]
# ### TEMA

# %% [markdown]
# El objetivo es identificar qué países ofrecen mejores condiciones de seguridad para las mujeres y qué factores explican estas diferencias. Este proyecto analiza la seguridad femenina a nivel global combinando indicadores de:
# - percepción de seguridad (caminar sola de noche)
# - seguridad en el hogar
# - igualdad legal
# - derechos de movilidad
# - protección jurídica

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %% [markdown]
# - Hipótesis 1:
# Los países con mayor igualdad legal presentan mejores indicadores de seguridad femenina.
# - Hipótesis 2:
# La percepción de seguridad no siempre coincide con los datos reales de criminalidad o protección legal.
# - Hipótesis 3:
# Europa Occidental es la región donde las mujeres se sienten más seguras.
# - Hipótesis 4:
# España está mejor posicionada de lo que solemos pensar.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
# guarda en variables los datasets y su fuente

fuente = "World Bank"

df_women_1 = pd.read_csv("data_women/WB_GS.csv") # Estadísticas de género, abarcan demografía, educación, salud, acceso a oportunidades económicas, vida pública, toma de decisiones, autonomía y capacidad de acción

df_women_2 = pd.read_csv("data_women/WB_WBL.csv") # Mujeres, empresa y la ley, Tema de Seguridad

df_women_3 = pd.read_csv("data_women/WEF_TTDI_SAFEWALK.csv") # Seguridad al caminar sola de noche

df_women_4 = pd.read_csv("data_women/WB_SSGD_PCT_POP_UNSAFE_HOME.csv") # Inseguridad frente al crimen en el hogar

df_women_5 = pd.read_csv("data_women/GI_AII_82.csv") # Derecho a viajar de forma independiente

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
df_women_1.head()

# %%
df_women_2.head()
# Out:
#        STRUCTURE                STRUCTURE_ID ACTION FREQ REF_AREA   INDICATOR  \
# 0  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A      SRB  GD_WBL_ENT
# 1  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A      SRB  GD_WBL_ENT
# 2  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A      SRB  GD_WBL_ENT
# 3  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A      SRB  GD_WBL_ENT
# 4  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A      SRB  GD_WBL_ENT
#
#   SEX AGE URBANISATION UNIT_MEASURE  ...  \
# 0  _Z  _Z           _Z        SCORE  ...
# 1  _Z  _Z           _Z        SCORE  ...
# 2  _Z  _Z           _Z        SCORE  ...
# 3  _Z  _Z           _Z        SCORE  ...
# 4  _Z  _Z           _Z        SCORE  ...
#
#                               COMP_BREAKDOWN_2_LABEL COMP_BREAKDOWN_3_LABEL  \
# 0  Index component: Are there Government-Led Serv...         Not Applicable
# 1                                              Total         Not Applicable
# ...

# %%
df_women_3.head()
# Out:
#        STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL REF_AREA  \
# 0  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      ALB
# 1  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      ALB
# 2  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      ALB
# 3  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      ALB
# 4  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      ALB
#
#   REF_AREA_LABEL          INDICATOR  \
# 0        Albania  WEF_TTDI_SAFEWALK
# 1        Albania  WEF_TTDI_SAFEWALK
# 2        Albania  WEF_TTDI_SAFEWALK
# 3        Albania  WEF_TTDI_SAFEWALK
# 4        Albania  WEF_TTDI_SAFEWALK
#
#                              INDICATOR_LABEL SEX  ... UNIT_MULT_LABEL  \
# 0  Safety walking alone at night, 0-1 (best)  _T  ...           Units
# 1  Safety walking alone at night, 0-1 (best)  _T  ...           Units
# ...

# %%
df_women_4.head()
# Out:
#        STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL REF_AREA  \
# 0  datastructure  WB.DATA360:DS_DATA360(1.2)      I   _O      Other      AND
# 1  datastructure  WB.DATA360:DS_DATA360(1.2)      I   _O      Other      AND
# 2  datastructure  WB.DATA360:DS_DATA360(1.2)      I   _O      Other      AND
# 3  datastructure  WB.DATA360:DS_DATA360(1.2)      I   _O      Other      AND
# 4  datastructure  WB.DATA360:DS_DATA360(1.2)      I   _O      Other      AND
#
#   REF_AREA_LABEL                    INDICATOR  \
# 0        Andorra  WB_SSGD_PCT_POP_UNSAFE_HOME
# 1        Andorra  WB_SSGD_PCT_POP_UNSAFE_HOME
# 2        Andorra  WB_SSGD_PCT_POP_UNSAFE_HOME
# 3        Andorra  WB_SSGD_PCT_POP_UNSAFE_HOME
# 4        Andorra  WB_SSGD_PCT_POP_UNSAFE_HOME
#
#                                      INDICATOR_LABEL SEX  ... UNIT_MULT_LABEL  \
# 0  Percentage of population who feel unsafe from ...  _T  ...           Units
# ...

# %%
df_women_5.head()
# Out:
#        STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL REF_AREA  \
# 0  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      DZA
# 1  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      DZA
# 2  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      DZA
# 3  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      DZA
# 4  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      DZA
#
#   REF_AREA_LABEL  INDICATOR  \
# 0        Algeria  GI_AII_82
# 1        Algeria  GI_AII_82
# 2        Algeria  GI_AII_82
# 3        Algeria  GI_AII_82
# 4        Algeria  GI_AII_82
#
#                                      INDICATOR_LABEL SEX  ... UNIT_MULT_LABEL  \
# 0  In law, women have the right to independent tr...  _T  ...           Units
# 1  In law, women have the right to independent tr...  _T  ...           Units
# 2  In law, women have the right to independent tr...  _T  ...           Units
# ...

# %%
df_women_1.shape

# %%
df_women_2.shape
# Out:
# (30753, 41)

# %%
df_women_3.shape
# Out:
# (1107, 38)

# %%
df_women_4.shape
# Out:
# (1314, 40)

# %%
df_women_5.shape
# Out:
# (594, 38)

# %%
df_women_1.info()

# %%
df_women_2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 30753 entries, 0 to 30752
# Data columns (total 41 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   STRUCTURE               30753 non-null  str
#  1   STRUCTURE_ID            30753 non-null  str
#  2   ACTION                  30753 non-null  str
#  3   FREQ                    30753 non-null  str
#  4   REF_AREA                30753 non-null  str
#  5   INDICATOR               30753 non-null  str
#  6   SEX                     30753 non-null  str
#  7   AGE                     30753 non-null  str
#  8   URBANISATION            30753 non-null  str
#  9   UNIT_MEASURE            30753 non-null  str
#  10  COMP_BREAKDOWN_1        30753 non-null  str
#  11  COMP_BREAKDOWN_2        30753 non-null  str
#  12  COMP_BREAKDOWN_3        30753 non-null  str
#  13  TIME_PERIOD             30753 non-null  int64
#  14  OBS_VALUE               30753 non-null  str
# ...

# %%
df_women_3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1107 entries, 0 to 1106
# Data columns (total 38 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   STRUCTURE               1107 non-null   str
#  1   STRUCTURE_ID            1107 non-null   str
#  2   ACTION                  1107 non-null   str
#  3   FREQ                    1107 non-null   str
#  4   FREQ_LABEL              1107 non-null   str
#  5   REF_AREA                1107 non-null   str
#  6   REF_AREA_LABEL          1107 non-null   str
#  7   INDICATOR               1107 non-null   str
#  8   INDICATOR_LABEL         1107 non-null   str
#  9   SEX                     1107 non-null   str
#  10  SEX_LABEL               1107 non-null   str
#  11  AGE                     1107 non-null   str
#  12  AGE_LABEL               1107 non-null   str
#  13  URBANISATION            1107 non-null   str
#  14  URBANISATION_LABEL      1107 non-null   str
# ...

# %%
df_women_4.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1314 entries, 0 to 1313
# Data columns (total 40 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   STRUCTURE               1314 non-null   str
#  1   STRUCTURE_ID            1314 non-null   str
#  2   ACTION                  1314 non-null   str
#  3   FREQ                    1314 non-null   str
#  4   FREQ_LABEL              1314 non-null   str
#  5   REF_AREA                1314 non-null   str
#  6   REF_AREA_LABEL          1314 non-null   str
#  7   INDICATOR               1314 non-null   str
#  8   INDICATOR_LABEL         1314 non-null   str
#  9   SEX                     1314 non-null   str
#  10  SEX_LABEL               1314 non-null   str
#  11  AGE                     1314 non-null   str
#  12  AGE_LABEL               1314 non-null   str
#  13  URBANISATION            1314 non-null   str
#  14  URBANISATION_LABEL      1314 non-null   str
# ...

# %%
df_women_5.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 594 entries, 0 to 593
# Data columns (total 38 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   STRUCTURE               594 non-null    str
#  1   STRUCTURE_ID            594 non-null    str
#  2   ACTION                  594 non-null    str
#  3   FREQ                    594 non-null    str
#  4   FREQ_LABEL              594 non-null    str
#  5   REF_AREA                594 non-null    str
#  6   REF_AREA_LABEL          594 non-null    str
#  7   INDICATOR               594 non-null    str
#  8   INDICATOR_LABEL         594 non-null    str
#  9   SEX                     594 non-null    str
#  10  SEX_LABEL               594 non-null    str
#  11  AGE                     594 non-null    str
#  12  AGE_LABEL               594 non-null    str
#  13  URBANISATION            594 non-null    str
#  14  URBANISATION_LABEL      594 non-null    str
# ...

# %% [markdown]
# Propuesta 1: ¿Qué hace feliz a Europa?
# Idea general
# Título posible:
# “¿Qué hace feliz a Europa? Un análisis de felicidad, economía y cohesión social”
# Tema:
# Analizar por qué unos países europeos son más “felices” que otros, usando el World Happiness Report y variables socioeconómicas (PIB per cápita, esperanza de vida, apoyo social, etc.). Puedes centrarte en Europa y comparar regiones (Norte vs Sur, Este vs Oeste) y situar a España dentro del mapa.
# El World Happiness Report tiene datasets muy usados en proyectos de Data Science, con columnas como “Happiness Score”, “GDP per capita”, “Social support”, “Healthy life expectancy”, etc.
# Además, puedes cruzarlo con datos abiertos europeos (Eurostat / data.europa.eu) para añadir variables extra (por ejemplo, desempleo juvenil, gasto social, etc.).
# Hipótesis posibles
# - Hipótesis 1 (principal):
# “Los países europeos con mayor PIB per cápita y esperanza de vida presentan niveles de felicidad significativamente más altos.”
# - Hipótesis 2:
# “El apoyo social (social support) explica mejor la felicidad que el PIB per cápita.”
# - Hipótesis 3 (toque simpático):
# “Los países con clima más suave (menos extremos de temperatura) no son necesariamente los más felices.”
# - Hipótesis 4:
# “España se sitúa por encima de la media europea en felicidad, pero por debajo en percepción de corrupción.”
# Puedes jugar con mapas, heatmaps de correlación, comparaciones por regiones, etc., encajando muy bien con la guía de EDA que te han dado (univariante, bivariante, multivariante).
