# %% [markdown]
#    #                                                  Titanic Exercise
#
#    ![titanic](https://userscontent2.emaze.com/images/a5f68f37-6349-4065-a1fc-921cbe7401b2/958230111417e36d6b3c67ffd7bc3494.jpeg)
#    #### Practise Pandas

# %% [markdown]
# First of all, import the needed libraries.

# %%
import pandas as pd
import random # en el ejercicio 10 necesio números aleatorios
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1. Read in filename and call the variable `titanic`
#     - Explore the `titanic` dataset using `info`, `dtypes` & `describe`

# %%
titanic = pd.read_csv("data/titanic.csv")

# %%
'''
primero voy a ubicarme con lo que significa cada columna, que luego me lío


pclass: clase del pasajero (1,2,3)

survived: sobrevivió =1, palmó = 0.

name: nombre del pasajero (algunos tienentítulo)

sex: male o female

age: edad en años

sibsp: num de hermanos o merido/mujer que viajaban con esa persona

parch: num de padres o hijos que viajaban con esa persona

ticket: num billete

fare: precio/billete

cabin: num de camarote

embarked: puerto donde embarcó, C= cherbourg, Q= queenstown, S= southampton

boat: num d el bote salvavidas en el que fue rescatado (si sobrevivió)

body: num de id del cuerpo recuperado (si palmó)

home.dest: destino finaldel pasajero

'''
# Out:
# '\nprimero voy a ubicarme con lo que significa cada columna, que luego me lío\n\n\npclass: clase del pasajero (1,2,3)\n\nsurvived: sobrevivió =1, palmó = 0.\n\nname: nombre del pasajero (algunos tienentítulo)\n\nsex: male o female\n\nage: edad en años\n\nsibsp: num de hermanos o merido/mujer que viajaban con esa persona\n\nparch: num de padres o hijos que viajaban con esa persona\n\nticket: num billete\n\nfare: precio/billete\n\ncabin: num de camarote\n\nembarked: puerto donde embarcó, C= cherbourg, Q= queenstown, S= southampton\n\nboat: num d el bote salvavidas en el que fue rescatado (si sobrevivió)\n\nbody: num de id del cuerpo recuperado (si palmó)\n\nhome.dest: destino finaldel pasajero\n\n'

# %%
titanic.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   str
#  3   sex        1309 non-null   str
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   str
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    str
#  10  embarked   1307 non-null   str
#  11  boat       486 non-null    str
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    str
# dtypes: float64(3), int64(4), str(7)
# memory usage: 143.3 KB

# %%
titanic.dtypes
# Out:
# pclass         int64
# survived       int64
# name             str
# sex              str
# age          float64
# sibsp          int64
# parch          int64
# ticket           str
# fare         float64
# cabin            str
# embarked         str
# boat             str
# body         float64
# home.dest        str
# dtype: object

# %%
titanic.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# 2. Create a separate dataframe with the columns `['name', 'sex', 'age']`, call it `people`
#
# It can be done two ways, do it both!

# %%
people = titanic[['name', 'sex', 'age']]
people
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %%
people2 = titanic.loc[:, ['name', 'sex', 'age']]
people2
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %% [markdown]
# 3. Print the output of `people` showing the first three rows and the last four rows, using `append`,`tail` and `head`

# %%
pd.concat([people.head(3), people.tail(4)])
# Out:
#                                 name     sex    age
# 0      Allen, Miss. Elisabeth Walton  female  29.00
# 1     Allison, Master. Hudson Trevor    male   0.92
# 2       Allison, Miss. Helen Loraine  female   2.00
# 1305           Zabour, Miss. Thamine  female    NaN
# 1306       Zakarian, Mr. Mapriededer    male  26.50
# 1307             Zakarian, Mr. Ortin    male  27.00
# 1308              Zimmerman, Mr. Leo    male  29.00

# %%
# ponía usar append y en el anterior no lo hice así, ahora sí:

first_3 = people.head(3)
last_4 = people.tail(4)

resultado = first_3.append(last_4)

resultado
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10720\4066140950.py in ?()
#       2
#       3 first_3 = people.head(3)
#       4 last_4 = people.tail(4)
#       5
# ----> 6 resultado = first_3.append(last_4)
#       7
#       8 resultado
#
# c:\Users\titea\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %% [markdown]
# 4. Slice the row from 3 to 9, call it `s_titanic`

# %%
titanic.iloc[3:10]
# Out:
#    pclass  survived                                             name     sex  \
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5       1         1                              Anderson, Mr. Harry    male
# 6       1         1                Andrews, Miss. Kornelia Theodosia  female
# 7       1         0                           Andrews, Mr. Thomas Jr    male
# 8       1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9       1         0                          Artagaveytia, Mr. Ramon    male
#
#     age  sibsp  parch    ticket      fare    cabin embarked boat   body  \
# 3  30.0      1      2    113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0      1      2    113781  151.5500  C22 C26        S  NaN    NaN
# 5  48.0      0      0     19952   26.5500      E12        S    3    NaN
# ...

# %% [markdown]
# 5. Slice the row from 40 to 63 in reverse order, call it `s_titanic_rev`

# %%
s_titanic_rev = titanic.iloc[40:64][::-1] # reverse!!!

s_titanic_rev
# Out:
#     pclass  survived                                               name  \
# 63       1         1  Chaffee, Mrs. Herbert Fuller (Carrie Constance...
# 62       1         0                        Chaffee, Mr. Herbert Fuller
# 61       1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 60       1         0                      Cavendish, Mr. Tyrell William
# 59       1         1  Cassebeer, Mrs. Henry Arthur Jr (Eleanor Genev...
# 58       1         0                             Case, Mr. Howard Brown
# 57       1         1          Carter, Mrs. William Ernest (Lucile Polk)
# 56       1         1                         Carter, Mr. William Ernest
# 55       1         1                          Carter, Miss. Lucile Polk
# 54       1         1                Carter, Master. William Thornton II
# 53       1         0                             Carrau, Mr. Jose Pedro
# 52       1         0                            Carrau, Mr. Francisco M
# ...

# %% [markdown]
# 6. Slice the columns from the starting column to `'parch'`, call it `left_columns`

# %%
left_columns = titanic.loc[:, : 'parch']

left_columns
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch
# 0     female  29.00      0      0
# ...

# %% [markdown]
# 7. Slice the columns from `'name'` to `'age'`, call it `middle_columns`

# %%
middle_columns = titanic.loc[:, 'name':'age']

middle_columns
# Out:
#                                                  name     sex    age
# 0                       Allen, Miss. Elisabeth Walton  female  29.00
# 1                      Allison, Master. Hudson Trevor    male   0.92
# 2                        Allison, Miss. Helen Loraine  female   2.00
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00
# ...                                               ...     ...    ...
# 1304                             Zabour, Miss. Hileni  female  14.50
# 1305                            Zabour, Miss. Thamine  female    NaN
# 1306                        Zakarian, Mr. Mapriededer    male  26.50
# 1307                              Zakarian, Mr. Ortin    male  27.00
# 1308                               Zimmerman, Mr. Leo    male  29.00
#
# [1309 rows x 3 columns]

# %% [markdown]
# 8. Slice the columns from `'ticket'` to the end, call it `right_columns`

# %%
right_columns = titanic.loc[:, 'ticket':]

right_columns
# Out:
#       ticket      fare    cabin embarked boat   body  \
# 0      24160  211.3375       B5        S    2    NaN
# 1     113781  151.5500  C22 C26        S   11    NaN
# 2     113781  151.5500  C22 C26        S  NaN    NaN
# 3     113781  151.5500  C22 C26        S  NaN  135.0
# 4     113781  151.5500  C22 C26        S  NaN    NaN
# ...      ...       ...      ...      ...  ...    ...
# 1304    2665   14.4542      NaN        C  NaN  328.0
# 1305    2665   14.4542      NaN        C  NaN    NaN
# 1306    2656    7.2250      NaN        C  NaN  304.0
# 1307    2670    7.2250      NaN        C  NaN    NaN
# 1308  315082    7.8750      NaN        S  NaN    NaN
#
#                             home.dest
# 0                        St Louis, MO
# 1     Montreal, PQ / Chesterville, ON
# 2     Montreal, PQ / Chesterville, ON
# 3     Montreal, PQ / Chesterville, ON
# 4     Montreal, PQ / Chesterville, ON
# ...                               ...
# 1304                              NaN
# ...

# %% [markdown]
# 9. What is the name of the oldest person who died in the Titanic? Was he or she travelling alone or had any family travelling with them?

# %% [markdown]
# In order to give an answer to the second question you should find out which columns give you that info. Usually part of your job as a Data Scientist will be get to know the dataset which you are working with. In this case the columns which give you that info are the following:
#         - 'sibsp' Number of Siblings/Spouses Aboard
#         - 'parch' Number of Parents/Children Aboard

# %%
dead = titanic[titanic['survived'] == 0]
oldest_dead = dead.loc[dead['age'].idxmax()]

'''
lo había puesto como aquí abajo para que saliera cuqui, pero en el siguiente necesito la variable 'oldest_dead':

dead = titanic[titanic['survived'] == 0]

dead.loc[[dead['age'].idxmax()]]
'''

oldest_dead
# Out:
# pclass                         3
# survived                       0
# name         Svensson, Mr. Johan
# sex                         male
# age                         74.0
# sibsp                          0
# parch                          0
# ticket                    347060
# fare                       7.775
# cabin                        NaN
# embarked                       S
# boat                         NaN
# body                         NaN
# home.dest                    NaN
# Name: 1235, dtype: object

# %%
oldest_dead_name = oldest_dead['name']

oldest_dead[['sibsp', 'parch']]
# Out:
# sibsp    0
# parch    0
# Name: 1235, dtype: object

# %%
print(f"Hermanos de {oldest_dead_name}:", oldest_dead['sibsp'])
print(f"Padres o hijos de {oldest_dead_name}:", oldest_dead['parch'])
print("Pobre, murió solo :(")
# Out:
# Hermanos de Svensson, Mr. Johan: 0
# Padres o hijos de Svensson, Mr. Johan: 0
# Pobre, murió solo :(

# %% [markdown]
# 10. Create the list of 5 random numbers of rows from 0 to the lenght of the dataframe, call it `rows`
#
# ex. `rows = [3,7,99,52,48]` use `random` library

# %% [markdown]
# This list of numbers are random, could be different.

# %%
rows = random.sample(range(len(titanic)), 5) # muestra una serie aleatoria de elementos únicos de una secuencia (lista, tupla, cadena o rango) sin reemplazo

rows
# Out:
# [795, 617, 811, 1051, 534]

# %% [markdown]
# 11. Create the list of three column labels, call it `cols`

# %%
cols = ['name', 'sex', 'age']

cols
# Out:
# ['name', 'sex', 'age']

# %%
# Obtenemos índices aleatorios
columnas = [random.randint(0, len(titanic.columns) - 1) for _ in range(3)]

# %%
# Buscamos los nombres de las columnas con esos índices
cols2 = [titanic.columns[c] for c in columnas]

cols2
# Out:
# ['age', 'fare', 'survived']

# %%
# otra manera
cols3 = [random.choice(list(titanic.columns)) for _ in range(3)]

cols3
# Out:
# ['cabin', 'pclass', 'parch']

# %% [markdown]
# 12. Use both lists `rows` and `cols` to create a new dataframe

# %%
new_df = titanic.loc[rows, cols]

titanic.loc[rows, cols] # lo repito para que se vea cuqui
# Out:
#                                                    name     sex   age
# 795                             Emir, Mr. Farred Chehab    male   NaN
# 617                                    Ali, Mr. William    male  25.0
# 811             Ford, Mrs. Edward (Margaret Ann Watson)  female  48.0
# 1051                       Nancarrow, Mr. William Henry    male  33.0
# 534   Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0

# %% [markdown]
# 13. Create a boolean array with the condition of being a woman or a man, using the `sex` column, where **female** is True. Call it `array_fe`

# %%
array_fe = titanic['sex'] == 'female'

array_fe # para ver que cambió a True las mujeres y False los hombres
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4        True
#         ...
# 1304     True
# 1305     True
# 1306    False
# 1307    False
# 1308    False
# Name: sex, Length: 1309, dtype: bool

# %% [markdown]
# 14. Rename the column `"sex"` to `"gender"` and filter the `titanic` dataframe with the boolean array, call it `woman_titanic`

# %%
titanic = titanic.rename(columns={'sex': 'gender'})

woman_titanic = titanic[array_fe] # ahora filtro

woman_titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 2          1         0                     Allison, Miss. Helen Loraine
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
#
#       gender   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %% [markdown]
# 15. How many woman were younger than 18? Call the variable `minor_wo`

# %%
minor_wo = woman_titanic[woman_titanic['age'] < 18].shape[0]

minor_wo
# Out:
# 72

# %%
minor_wo = woman_titanic[woman_titanic['age'] < 18] # por si necesito la lista y no el número 

len(minor_wo)
minor_wo.shape[0]
# Out:
# 72

# %% [markdown]
# 16. How many woman that were less than 18 actually died? Call the variable `dead_wo`

# %%
dead_wo = woman_titanic[(woman_titanic['age'] < 18) & (woman_titanic['survived'] == 0)].shape[0]

dead_wo

# .lt(18) es lo mismo que poner <18
# .gt(18) es lo mismo que poner >18
# .le(18) <=18
# .ge(18) >=18
# Out:
# 22

# %% [markdown]
# 17. Drop rows with *Nan* in `titanic` with `how='any'` and print the shape

# %%
titanic.dropna(how='any').shape
# me quedo sin filas, quitan las filas con algun nulo
# Out:
# (0, 14)

# %% [markdown]
# 18. Drop rows with *Nan* in `titanic` with `how='all'` and print the shape

# %%
titanic.dropna(how='all').shape
# coge todas las filas con NaN, todas tienen algun NaN
# Out:
# (1309, 14)

# %% [markdown]
# Check in [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html) why the shapes are different.

# %% [markdown]
# 19. Drop columns in `titanic` with more than 1000 missing values and print the columns remaining

# %%
cols_to_drop = titanic.columns[titanic.isna().sum() > 1000]

titanic_clean = titanic.drop(columns=cols_to_drop)

titanic_clean.columns
# Out:
# Index(['pclass', 'survived', 'name', 'gender', 'age', 'sibsp', 'parch',
#        'ticket', 'fare', 'embarked', 'boat', 'home.dest'],
#       dtype='str')

# %%
titanic.dropna(axis=1, thresh=len(titanic) - 1000) # thresh numero minimo de valores buenos (no nulos) que fijas como umbral y pasa el filtro, es decir, que no lo borra
# conservar las filas(axis=1) que tengan por lo menos el thresh de valores buenos
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#       gender    age  sibsp  parch  ticket      fare embarked boat  \
# ...

# %% [markdown]
# 20. Calculate the ratio of missing values at the `boat` column.

# %%
titanic['boat'].isna().mean()
# Out:
# np.float64(0.6287242169595111)

# %% [markdown]
# 21.  Group `titanic` by `'pclass'` and aggregate by the columns `age` & `fare`, by `max` and `median` and assign it to `by_class`

# %%
by_class = titanic.groupby('pclass')[['age', 'fare']].agg(['max', 'median'])

by_class
# Out:
#          age             fare
#          max median       max   median
# pclass
# 1       80.0   39.0  512.3292  60.0000
# 2       70.0   29.0   73.5000  15.0458
# 3       74.0   24.0   69.5500   8.0500

# %% [markdown]
# 22. Print the maximum age in each class from `by_class`

# %%
by_class[[('age','max')]] # porque es un multiindice, que son tuplas, y así lo pongo para que quede cuqui
# Out:
#          age
#          max
# pclass
# 1       80.0
# 2       70.0
# 3       74.0

# %% [markdown]
# 23. Print the median fare in each class from `by_class`

# %%
by_class[[('fare','median')]]
# Out:
#            fare
#          median
# pclass
# 1       60.0000
# 2       15.0458
# 3        8.0500

# %% [markdown]
# 24. Using [`.pivot_table()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html) to count how many women or men survived by class, call it `counted`.
#
# Don't panic and read the documentation!

# %%
counted = titanic.pivot_table(values='survived', index='pclass', columns='gender', aggfunc='sum')

counted
# Out:
# gender  female  male
# pclass
# 1          139    61
# 2           94    25
# 3          106    75

# %% [markdown]
# 25. Add a new column with the sum of survived men and women, call it `counted['total']`

# %%
counted['total'] = counted.sum(axis=1) # esto no, porque quiere suma de mujers y hombres, pero aparte

counted
# Out:
# gender  female  male  total
# pclass
# 1          139    61  600.0
# 2           94    25  357.0
# 3          106    75  543.0

# %%
counted2 = titanic.pivot_table(values='survived', index='gender', columns='pclass', aggfunc='sum')
counted2
# Out:
# pclass    1   2    3
# gender
# female  139  94  106
# male     61  25   75

# %%
counted2['total2'] = counted2.sum(axis=1)
counted2
# Out:
# pclass    1   2    3  total2
# gender
# female  139  94  106     339
# male     61  25   75     161

# %% [markdown]
# 26. Sort `counted` by the `'total'` column. In which class the people survived the most?

# %%
counted.sort_values('total', ascending=False)
# Out:
# gender  female  male  total
# pclass
# 1          139    61  600.0
# 3          106    75  543.0
# 2           94    25  357.0

# %% [markdown]
# 27. Please, show only the rows using a mask with the following conditions:
#     - They are woman
#     - From third class
#     - Younger than 30
#     - They survived
#
#     ¿How many rows fulfill the condition?

# %%
mask = (titanic['gender']=='female') & (titanic['pclass']==3) & (titanic['age']<30) & (titanic['survived']==1)


mask
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Length: 1309, dtype: bool

# %%
titanic[mask].shape[0]
# Out:
# 57

# %% [markdown]
# 28. Now, show only the rows using `.loc` with the following conditions:
#     - They are man
#     - From first class
#     - Older than 50
#     - They died
#
#     ¿How many rows fulfill the condition?

# %%
mask2 = (titanic['gender']=='male') & (titanic['pclass']==1) & (titanic['age']>50) & (titanic['survived']==0)

mask2
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1304    False
# 1305    False
# 1306    False
# 1307    False
# 1308    False
# Length: 1309, dtype: bool

# %%
titanic.loc[mask2].shape[0]
# Out:
# 29

# %% [markdown]
# 29. Print the uniques values at the column `'name'`

# %%
titanic['name'].unique()
# Out:
# <StringArray>
# [                  'Allen, Miss. Elisabeth Walton',
#                   'Allison, Master. Hudson Trevor',
#                     'Allison, Miss. Helen Loraine',
#             'Allison, Mr. Hudson Joshua Creighton',
#  'Allison, Mrs. Hudson J C (Bessie Waldo Daniels)',
#                              'Anderson, Mr. Harry',
#                'Andrews, Miss. Kornelia Theodosia',
#                           'Andrews, Mr. Thomas Jr',
#    'Appleton, Mrs. Edward Dale (Charlotte Lamson)',
#                          'Artagaveytia, Mr. Ramon',
#  ...
#                              'Yasbeck, Mr. Antoni',
#          'Yasbeck, Mrs. Antoni (Selini Alexander)',
#                             'Youseff, Mr. Gerious',
#                                'Yousif, Mr. Wazli',
#                            'Yousseff, Mr. Gerious',
#                             'Zabour, Miss. Hileni',
#                            'Zabour, Miss. Thamine',
#                        'Zakarian, Mr. Mapriededer',
# ...

# %%
# versión cuqui
list(titanic['name'].unique())
# Out:
# ['Allen, Miss. Elisabeth Walton',
#  'Allison, Master. Hudson Trevor',
#  'Allison, Miss. Helen Loraine',
#  'Allison, Mr. Hudson Joshua Creighton',
#  'Allison, Mrs. Hudson J C (Bessie Waldo Daniels)',
#  'Anderson, Mr. Harry',
#  'Andrews, Miss. Kornelia Theodosia',
#  'Andrews, Mr. Thomas Jr',
#  'Appleton, Mrs. Edward Dale (Charlotte Lamson)',
#  'Artagaveytia, Mr. Ramon',
#  'Astor, Col. John Jacob',
#  'Astor, Mrs. John Jacob (Madeleine Talmadge Force)',
#  'Aubart, Mme. Leontine Pauline',
#  'Barber, Miss. Ellen "Nellie"',
#  'Barkworth, Mr. Algernon Henry Wilson',
#  'Baumann, Mr. John D',
#  'Baxter, Mr. Quigg Edmond',
#  'Baxter, Mrs. James (Helene DeLaudeniere Chaput)',
#  'Bazzani, Miss. Albina',
#  'Beattie, Mr. Thomson',
#  'Beckwith, Mr. Richard Leonard',
#  'Beckwith, Mrs. Richard Leonard (Sallie Monypeny)',
#  'Behr, Mr. Karl Howell',
#  'Bidois, Miss. Rosalie',
#  'Bird, Miss. Ellen',
#  'Birnbaum, Mr. Jakob',
#  'Bishop, Mr. Dickinson H',
# ...

# %% [markdown]
# 30. Find if was there any `name` repeated at the Titanic?
#
# Hint: There were two people with the same name, who?

# %%
titanic['name'].value_counts()[titanic['name'].value_counts() > 1]
# Out:
# name
# Connolly, Miss. Kate    2
# Kelly, Mr. James        2
# Name: count, dtype: int64

# %%
# otra forma
titanic[titanic["name"].duplicated(keep=False)]
# Out:
#      pclass  survived                  name  gender   age  sibsp  parch  \
# 725       3         1  Connolly, Miss. Kate  female  22.0      0      0
# 726       3         0  Connolly, Miss. Kate  female  30.0      0      0
# 924       3         0      Kelly, Mr. James    male  34.5      0      0
# 925       3         0      Kelly, Mr. James    male  44.0      0      0
#
#      ticket    fare cabin embarked boat  body home.dest
# 725  370373  7.7500   NaN        Q   13   NaN   Ireland
# 726  330972  7.6292   NaN        Q  NaN   NaN   Ireland
# 924  330911  7.8292   NaN        Q  NaN  70.0       NaN
# 925  363592  8.0500   NaN        S  NaN   NaN       NaN

# %% [markdown]
# 31. Using `matplotlib` find the appropriate visualization to show the distribution of the column `'age'`

# %%
plt.hist(titanic['age'].dropna(), bins=20, edgecolor="black")
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
plt.hist(titanic['age'], bins=20, edgecolor="black"); # ; pa que no te salga la info del objeto

# %% [markdown]
# 32. Using `matplotlib` find the appropriate plot to visualize the column `'gender'`

# %%
count= titanic['gender'].value_counts()
plt.bar(count.index, count.values)
plt.xlabel('Gender');
# plt.show() no hace falta, solo en los scripts(.py)

# %%
# urko style: otra manera con el pastelito
counts = titanic['gender'].value_counts()

plt.pie(counts.values, labels=counts.index, autopct='%1.1f%%') # autopct='%1.1f%%' esto es para que me salga el porcentaje
plt.title('Proportion of Gender');

# %% [markdown]
# 32b. What if you also plot the column `'gender'` using the function [`countplot`](https://seaborn.pydata.org/generated/seaborn.countplot.html) from the library [`seaborn`](https://seaborn.pydata.org/)?
#
# Remember you have never used `seaborn` before, therefore you should install it before importing it.

# %%
sns.countplot(data=titanic, x='gender');

# %% [markdown]
# 33. Using the function [`catplot`](https://seaborn.pydata.org/generated/seaborn.catplot.html) from the library `seaborn`, find out if the hypothesis _"Women are more likely to survive shipwrecks"_ is true or not.
#
# You should get something like this:

# %% [markdown]
# ![catplot](./img/catplotgen.png)

# %%
sns.catplot(data=titanic, x='gender', y='survived', hue='gender', kind='bar');

# %% [markdown]
# 34. Using [`kdeplot`]("https://seaborn.pydata.org/generated/seaborn.kdeplot.html") from `seaborn` represent those who not survived distributed by age.<>
#
# Hint: First you should "filter" the `titanic` dataset where the column "survived" is 0, indexing the column `"age"` only.
#
# Arguments you should pass to the function:
#
#     - color = "red"
#     - label = "Not Survived"
#     - shade = True
#
# You should get something like this:

# %% [markdown]
# ![kdeplot](./img/kdeplotsur.png)

# %%
dead = titanic[titanic['survived']==0]

sns.kdeplot(dead['age'].dropna(), color='red', label='Not Survived', fill=True)
plt.legend();
